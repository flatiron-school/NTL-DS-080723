# %%
import pandas as pd

import seaborn as sns

from sklearn.linear_model import LinearRegression, Ridge
from sklearn.dummy import DummyRegressor
from sklearn.preprocessing import StandardScaler, OneHotEncoder, PolynomialFeatures
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import train_test_split

# %%
#data

df = pd.read_csv('./data/hour.csv', index_col='instant', parse_dates=['dteday'])

# %%
df.head()
# Out:
#             dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# instant
# 1       2011-01-01       1   0     1   0        0        6           0
# 2       2011-01-01       1   0     1   1        0        6           0
# 3       2011-01-01       1   0     1   2        0        6           0
# 4       2011-01-01       1   0     1   3        0        6           0
# 5       2011-01-01       1   0     1   4        0        6           0
#
#          weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# instant
# 1                 1  0.24  0.2879  0.81        0.0       3          13   16
# 2                 1  0.22  0.2727  0.80        0.0       8          32   40
# 3                 1  0.22  0.2727  0.80        0.0       5          27   32
# 4                 1  0.24  0.2879  0.75        0.0       3          10   13
# 5                 1  0.24  0.2879  0.75        0.0       0           1    1

# %%
df.dtypes
# Out:
# dteday        datetime64[ns]
# season                 int64
# yr                     int64
# mnth                   int64
# hr                     int64
# holiday                int64
# weekday                int64
# workingday             int64
# weathersit             int64
# temp                 float64
# atemp                float64
# hum                  float64
# windspeed            float64
# casual                 int64
# registered             int64
# cnt                    int64
# dtype: object

# %%
df.describe()
# Out:
#              season            yr          mnth            hr       holiday  \
# count  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000
# mean       2.501640      0.502561      6.537775     11.546752      0.028770
# std        1.106918      0.500008      3.438776      6.914405      0.167165
# min        1.000000      0.000000      1.000000      0.000000      0.000000
# 25%        2.000000      0.000000      4.000000      6.000000      0.000000
# 50%        3.000000      1.000000      7.000000     12.000000      0.000000
# 75%        3.000000      1.000000     10.000000     18.000000      0.000000
# max        4.000000      1.000000     12.000000     23.000000      1.000000
#
#             weekday    workingday    weathersit          temp         atemp  \
# count  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000
# mean       3.003683      0.682721      1.425283      0.496987      0.475775
# ...

# %%
sns.pairplot(df[['temp','atemp','hum','windspeed','cnt']]);

# %%
df[['temp','atemp','hum','windspeed','cnt']].corr()
# Out:
#                temp     atemp       hum  windspeed       cnt
# temp       1.000000  0.987672 -0.069881  -0.023125  0.404772
# atemp      0.987672  1.000000 -0.051918  -0.062336  0.400929
# hum       -0.069881 -0.051918  1.000000  -0.290105 -0.322911
# windspeed -0.023125 -0.062336 -0.290105   1.000000  0.093234
# cnt        0.404772  0.400929 -0.322911   0.093234  1.000000

# %%
sns.heatmap(df[['temp','atemp','hum','windspeed','cnt']].corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
X = df.drop(['atemp','casual','registered','cnt'], axis = 1).reset_index(drop=True)
y = df.cnt.reset_index(drop=True)

# %%
X_train, y_train, x_test, y_test = train_test_split(X,y, random_state = 42)

# %%
X.head(1)
# Out:
#       dteday  season  yr  mnth  hr  holiday  weekday  workingday  weathersit  \
# 0 2011-01-01       1   0     1   0        0        6           0           1
#
#    temp   hum  windspeed
# 0  0.24  0.81        0.0

# %%
numcols = ['temp','hum','windspeed']

# %%
catcols = ['season', 'month','hour','weekday','weathersit']

# %%
lr = LinearRegression().fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-37-7bdffdb070fa> in <module>
# ----> 1 lr = LinearRegression().fit(X_train, y_train)
#
# ~\anaconda3\envs\learn-env\lib\site-packages\sklearn\linear_model\_base.py in fit(self, X, y, sample_weight)
#     503
#     504         n_jobs_ = self.n_jobs
# --> 505         X, y = self._validate_data(X, y, accept_sparse=['csr', 'csc', 'coo'],
#     506                                    y_numeric=True, multi_output=True)
#     507
#
# ~\anaconda3\envs\learn-env\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     430                 y = check_array(y, **check_y_params)
#     431             else:
# --> 432                 X, y = check_X_y(X, y, **check_params)
#     433             out = X, y
#     434
#
# ...

# %%
#numerics

num_sub = Pipeline

# %%
#cats 

cat_sub = Pipeline

# %%
# Deal withh all the columns

CT = ColumnTransformer

# %%
#dummy

dum_pipe = Pipeline

# %%
# FSM

fsm_pipe = Pipeline

# %%
# add poly

# %%
# ridge?
